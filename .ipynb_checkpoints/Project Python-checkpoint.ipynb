# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
rawdata = pd.read_excel('c://Users//Matthew//DA//Activities//midproject//data_mid_bootcamp_project_regression//regression_data.xls')

# %%
pd.set_option('display.max_columns',None)
rawdata.head()
# Out:
#            id       date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520 2014-10-13         3       1.00         1180      5650     1.0
# 1  6414100192 2014-12-09         3       2.25         2570      7242     2.0
# 2  5631500400 2015-02-25         2       1.00          770     10000     1.0
# 3  2487200875 2014-12-09         4       3.00         1960      5000     1.0
# 4  1954400510 2015-02-18         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        1180              0      1955
# 1           0     0          3      7        2170            400      1951
# 2           0     0          3      6         770              0      1933
# 3           0     0          5      7        1050            910      1965
# 4           0     0          3      8        1680              0      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15   price
# 0             0    98178  47.5112 -122.257           1340        5650  221900
# 1          1991    98125  47.7210 -122.319           1690        7639  538000
# 2             0    98028  47.7379 -122.233           2720        8062  180000
# 3             0    98136  47.5208 -122.393           1360        5000  604000
# 4             0    98074  47.6168 -122.045           1800        7503  510000

# %%
rawdata.shape
# Out:
# (21597, 21)

# %%
rawdata.dtypes
# Out:
# id                        int64
# date             datetime64[ns]
# bedrooms                  int64
# bathrooms               float64
# sqft_living               int64
# sqft_lot                  int64
# floors                  float64
# waterfront                int64
# view                      int64
# condition                 int64
# grade                     int64
# sqft_above                int64
# sqft_basement             int64
# yr_built                  int64
# yr_renovated              int64
# zipcode                   int64
# lat                     float64
# long                    float64
# sqft_living15             int64
# sqft_lot15                int64
# price                     int64
# dtype: object

# %%
cleandata = rawdata
cleandata.head()
# Out:
#            id       date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520 2014-10-13         3       1.00         1180      5650     1.0
# 1  6414100192 2014-12-09         3       2.25         2570      7242     2.0
# 2  5631500400 2015-02-25         2       1.00          770     10000     1.0
# 3  2487200875 2014-12-09         4       3.00         1960      5000     1.0
# 4  1954400510 2015-02-18         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        1180              0      1955
# 1           0     0          3      7        2170            400      1951
# 2           0     0          3      6         770              0      1933
# 3           0     0          5      7        1050            910      1965
# 4           0     0          3      8        1680              0      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15   price
# 0             0    98178  47.5112 -122.257           1340        5650  221900
# 1          1991    98125  47.7210 -122.319           1690        7639  538000
# 2             0    98028  47.7379 -122.233           2720        8062  180000
# 3             0    98136  47.5208 -122.393           1360        5000  604000
# 4             0    98074  47.6168 -122.045           1800        7503  510000

# %%
rawdata.shape
# Out:
# (21597, 21)

# %%
cleandata=cleandata.drop_duplicates()
cleandata.shape
# Out:
# (21597, 21)

# %%
# cleandata=cleandata.drop_duplicates(subset = ['bedrooms','bathrooms'])
#eliminates all dupes of rows with all the same values of the subset columns

# %%
cleandata[cleandata['id']==795000620]
# Out:
#               id       date  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 17588  795000620 2014-09-24         3        1.0         1080      6250
# 17589  795000620 2014-12-15         3        1.0         1080      6250
# 17590  795000620 2015-03-11         3        1.0         1080      6250
#
#        floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 17588     1.0           0     0          2      5        1080              0
# 17589     1.0           0     0          2      5        1080              0
# 17590     1.0           0     0          2      5        1080              0
#
#        yr_built  yr_renovated  zipcode      lat    long  sqft_living15  \
# 17588      1950             0    98168  47.5045 -122.33           1070
# 17589      1950             0    98168  47.5045 -122.33           1070
# 17590      1950             0    98168  47.5045 -122.33           1070
#
#        sqft_lot15   price
# 17588        6250  115000
# 17589        6250  124000
# 17590        6250  157000

# %%
cleandata=cleandata.drop('id',axis=1)
cleandata.shape
# Out:
# (21597, 20)

# %%
cleandata['bedrooms']==33

# %%
cleandata=cleandata[~cleandata['bedrooms'].isin([33])]
cleandata.shape
# Out:
# (21596, 20)

# %%
cleandata[ (cleandata['bedrooms']== 33) ]
# Out:
# Empty DataFrame
# Columns: [date, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, grade, sqft_above, sqft_basement, yr_built, yr_renovated, zipcode, lat, long, sqft_living15, sqft_lot15, price]
# Index: []

# %%
cleandata.sort_values(by=['date'])
# Out:
#             date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 15113 2014-05-02         2       1.00          850      6174     1.0
# 2485  2014-05-02         2       2.00         1350      2560     1.0
# 12484 2014-05-02         2       1.00          800      4850     1.0
# 4959  2014-05-02         3       1.75         2330     14892     1.0
# 18675 2014-05-02         5       2.50         2210      9655     1.0
# ...          ...       ...        ...          ...       ...     ...
# 20456 2015-05-14         5       3.00         3223      6371     2.0
# 927   2015-05-14         2       2.75         1370      1140     2.0
# 5632  2015-05-15         5       2.00         1870      7344     1.5
# 13040 2015-05-24         2       1.75         1390      6670     1.0
# 16580 2015-05-27         4       2.25         3750      5000     2.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 15113           0     0          4      7         850              0
# 2485            0     0          3      8        1350              0
# 12484           0     0          4      7         800              0
# 4959            0     0          3      8        1970            360
# 18675           0     0          3      8        1460            750
# ...           ...   ...        ...    ...         ...            ...
# 20456           0     0          3      9        3223              0
# 927             0     0          3      8        1080            290
# 5632            0     0          3      7        1870              0
# 13040           0     0          3      6         720            670
# 16580           0     0          5      8        2440           1310
#
#        yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 15113      1950             0    98155  47.7352 -122.328           1100
# 2485       1976             0    98052  47.6344 -122.107           1790
# 12484      1944             0    98107  47.6639 -122.364           1150
# 4959       1980             0    98074  47.6267 -122.046           2570
# 18675      1976             0    98011  47.7698 -122.222           2080
# ...         ...           ...      ...      ...      ...            ...
# 20456      2014             0    98042  47.3584 -122.163           1979
# 927        2009             0    98133  47.7052 -122.343           1370
# 5632       1960             0    98007  47.5951 -122.144           1870
# 13040      1941             0    98115  47.6914 -122.308            920
# 16580      1924             0    98115  47.6747 -122.303           2170
#
#        sqft_lot15    price
# 15113        6174   308500
# 2485         2560   335000
# 12484        4365   440000
# 4959        14217   588500
# 18675        8633   470000
# ...           ...      ...
# 20456        9008   479349
# 927          1090   359000
# 5632         7650   450000
# 13040        6380   445500
# 16580        4590  1310000
#
# [21596 rows x 20 columns]

# %%
period=pd.Period("2014-05-02", freq='D')
period.day_of_year
# Out:
# 122

# %%
pd.Period("2014-05-02").day_of_year
# Out:
# 2014

# %%
def daycount(x):
    period = pd.Period(x,freq='D')
    if period.year == 2014:
        return period.day_of_year - 122
    elif period.year == 2015:
        return period.day_of_year+243

# %%
cleandata['day']=list(map(daycount,cleandata['date']))

# %%
cleandata.sort_values(by=['date'])
# Out:
#             date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 15113 2014-05-02         2       1.00          850      6174     1.0
# 2485  2014-05-02         2       2.00         1350      2560     1.0
# 12484 2014-05-02         2       1.00          800      4850     1.0
# 4959  2014-05-02         3       1.75         2330     14892     1.0
# 18675 2014-05-02         5       2.50         2210      9655     1.0
# ...          ...       ...        ...          ...       ...     ...
# 20456 2015-05-14         5       3.00         3223      6371     2.0
# 927   2015-05-14         2       2.75         1370      1140     2.0
# 5632  2015-05-15         5       2.00         1870      7344     1.5
# 13040 2015-05-24         2       1.75         1390      6670     1.0
# 16580 2015-05-27         4       2.25         3750      5000     2.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 15113           0     0          4      7         850              0
# 2485            0     0          3      8        1350              0
# 12484           0     0          4      7         800              0
# 4959            0     0          3      8        1970            360
# 18675           0     0          3      8        1460            750
# ...           ...   ...        ...    ...         ...            ...
# 20456           0     0          3      9        3223              0
# 927             0     0          3      8        1080            290
# 5632            0     0          3      7        1870              0
# 13040           0     0          3      6         720            670
# 16580           0     0          5      8        2440           1310
#
#        yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 15113      1950             0    98155  47.7352 -122.328           1100
# 2485       1976             0    98052  47.6344 -122.107           1790
# 12484      1944             0    98107  47.6639 -122.364           1150
# 4959       1980             0    98074  47.6267 -122.046           2570
# 18675      1976             0    98011  47.7698 -122.222           2080
# ...         ...           ...      ...      ...      ...            ...
# 20456      2014             0    98042  47.3584 -122.163           1979
# 927        2009             0    98133  47.7052 -122.343           1370
# 5632       1960             0    98007  47.5951 -122.144           1870
# 13040      1941             0    98115  47.6914 -122.308            920
# 16580      1924             0    98115  47.6747 -122.303           2170
#
#        sqft_lot15    price  day
# 15113        6174   308500    0
# 2485         2560   335000    0
# 12484        4365   440000    0
# 4959        14217   588500    0
# 18675        8633   470000    0
# ...           ...      ...  ...
# 20456        9008   479349  377
# 927          1090   359000  377
# 5632         7650   450000  378
# 13040        6380   445500  387
# 16580        4590  1310000  390
#
# [21596 rows x 21 columns]

# %%
moddata = cleandata

# %%
#converting bath count from quarter counts to half counts (need to correct regex use)

def bathnum(x):
    x=str(x)
    if x[-2:] == '25':
        x=float(x)
        x=x+.25
        return x
    elif x[-2:] == '75':
        x=float(x)
        x=x+.25
        return x
    else:
        x=float(x)
        return x

# %%
moddata['new bath count']=list(map(bathnum,moddata['bathrooms']))

# %%
moddata
# Out:
#        bedrooms  bathrooms  floors  waterfront  view  condition  grade  \
# 0             3       1.00     1.0           0     0          3      7
# 1             3       2.25     2.0           0     0          3      7
# 2             2       1.00     1.0           0     0          3      6
# 3             4       3.00     1.0           0     0          5      7
# 4             3       2.00     1.0           0     0          3      8
# ...         ...        ...     ...         ...   ...        ...    ...
# 21592         3       2.50     3.0           0     0          3      8
# 21593         4       2.50     2.0           0     0          3      8
# 21594         2       0.75     2.0           0     0          3      7
# 21595         3       2.50     2.0           0     0          3      8
# 21596         2       0.75     2.0           0     0          3      7
#
#        sqft_above  sqft_basement  yr_built  zipcode  sqft_living15  \
# 0            1180              0      1955    98178           1340
# 1            2170            400      1951    98125           1690
# 2             770              0      1933    98028           2720
# 3            1050            910      1965    98136           1360
# 4            1680              0      1987    98074           1800
# ...           ...            ...       ...      ...            ...
# 21592        1530              0      2009    98103           1530
# 21593        2310              0      2014    98146           1830
# 21594        1020              0      2009    98144           1020
# 21595        1600              0      2004    98027           1410
# 21596        1020              0      2008    98144           1020
#
#        sqft_lot15  day      lat     long new reno  new bath count
# 0            5650  164  47.5112 -122.257       no             1.0
# 1            7639  221  47.7210 -122.319       no             2.5
# 2            8062  299  47.7379 -122.233       no             1.0
# 3            5000  221  47.5208 -122.393       no             3.0
# 4            7503  292  47.6168 -122.045       no             2.0
# ...           ...  ...      ...      ...      ...             ...
# 21592        1509   19  47.6993 -122.346       no             2.5
# 21593        7200  297  47.5107 -122.362       no             2.5
# 21594        2007   52  47.5944 -122.299       no             1.0
# 21595        1287  259  47.5345 -122.069       no             2.5
# 21596        1357  166  47.5941 -122.299       no             1.0
#
# [21596 rows x 18 columns]

# %%
moddata.drop(['date'],axis=1)
# Out:
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0             3       1.00         1180      5650     1.0           0     0
# 1             3       2.25         2570      7242     2.0           0     0
# 2             2       1.00          770     10000     1.0           0     0
# 3             4       3.00         1960      5000     1.0           0     0
# 4             3       2.00         1680      8080     1.0           0     0
# ...         ...        ...          ...       ...     ...         ...   ...
# 21592         3       2.50         1530      1131     3.0           0     0
# 21593         4       2.50         2310      5813     2.0           0     0
# 21594         2       0.75         1020      1350     2.0           0     0
# 21595         3       2.50         1600      2388     2.0           0     0
# 21596         2       0.75         1020      1076     2.0           0     0
#
#        condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0              3      7        1180              0      1955             0
# 1              3      7        2170            400      1951          1991
# 2              3      6         770              0      1933             0
# 3              5      7        1050            910      1965             0
# 4              3      8        1680              0      1987             0
# ...          ...    ...         ...            ...       ...           ...
# 21592          3      8        1530              0      2009             0
# 21593          3      8        2310              0      2014             0
# 21594          3      7        1020              0      2009             0
# 21595          3      8        1600              0      2004             0
# 21596          3      7        1020              0      2008             0
#
#        zipcode      lat     long  sqft_living15  sqft_lot15   price  day
# 0        98178  47.5112 -122.257           1340        5650  221900  164
# 1        98125  47.7210 -122.319           1690        7639  538000  221
# 2        98028  47.7379 -122.233           2720        8062  180000  299
# 3        98136  47.5208 -122.393           1360        5000  604000  221
# 4        98074  47.6168 -122.045           1800        7503  510000  292
# ...        ...      ...      ...            ...         ...     ...  ...
# 21592    98103  47.6993 -122.346           1530        1509  360000   19
# 21593    98146  47.5107 -122.362           1830        7200  400000  297
# 21594    98144  47.5944 -122.299           1020        2007  402101   52
# 21595    98027  47.5345 -122.069           1410        1287  400000  259
# 21596    98144  47.5941 -122.299           1020        1357  325000  166
#
# [21596 rows x 20 columns]

# %%
pd.set_option("display.max_rows",None)
moddata['yr_renovated'].value_counts()
# Out:
# 0       20682
# 2014       91
# 2013       37
# 2003       36
# 2007       35
# 2000       35
# 2005       35
# 2004       26
# 1990       25
# 2006       24
# 2009       22
# 2002       22
# 1989       22
# 1991       20
# 1994       19
# 1993       19
# 1998       19
# 2001       19
# 2010       18
# 1983       18
# 2008       18
# 1984       18
# 1987       18
# 1986       17
# 1985       17
# 1992       17
# 1999       17
# 1995       16
# 2015       16
# 1988       15
# 1996       15
# 1997       15
# 2011       13
# 1980       11
# 2012       11
# 1982       11
# 1979       10
# 1970        9
# 1968        8
# 1977        8
# 1978        6
# 1975        6
# 1964        5
# 1981        5
# 1958        5
# 1965        5
# 1973        5
# 1960        4
# 1972        4
# 1963        4
# 1969        4
# 1976        3
# 1956        3
# 1945        3
# 1957        3
# 1953        3
# 1974        3
# 1955        3
# 1950        2
# 1967        2
# 1971        2
# 1940        2
# 1962        2
# 1946        2
# 1934        1
# 1948        1
# 1954        1
# 1951        1
# 1944        1
# 1959        1
# Name: yr_renovated, dtype: int64

# %%
i=2
for col in cleandata.columns:
    print('For column ',col,',the counts are:',cleandata[col].value_counts())
    i+=1
# Out:
# For column  date ,the counts are: 2014-06-23    142
# 2014-06-26    131
# 2014-06-25    131
# 2014-07-08    127
# 2015-04-27    126
#              ...
# 2014-05-17      1
# 2014-07-27      1
# 2014-08-03      1
# 2014-11-02      1
# 2015-05-24      1
# Name: date, Length: 372, dtype: int64
# For column  bedrooms ,the counts are: 3     9824
# 4     6882
# 2     2760
# 5     1601
# 6      272
# 1      196
# 7       38
# 8       13
# 9        6
# 10       3
# 33       1
# 11       1
# Name: bedrooms, dtype: int64
# For column  bathrooms ,the counts are: 2.50    5377
# 1.00    3851
# 1.75    3048
# 2.25    2047
# 2.00    1930
# 1.50    1445
# 2.75    1185
# 3.00     753
# 3.50     731
# 3.25     589
# 3.75     155
# 4.00     136
# 4.50     100
# 4.25      79
# 0.75      71
# 4.75      23
# 5.00      21
# 5.25      13
# 5.50      10
# 1.25       9
# 6.00       6
# 5.75       4
# 0.50       4
# 6.25       2
# 8.00       2
# 6.75       2
# 6.50       2
# 7.75       1
# 7.50       1
# Name: bathrooms, dtype: int64
# For column  sqft_living ,the counts are: 1300    138
# 1400    135
# 1440    133
# 1010    129
# 1660    129
#        ...
# 2678      1
# 6900      1
# 6980      1
# 3078      1
# 2031      1
# Name: sqft_living, Length: 1034, dtype: int64
# For column  sqft_lot ,the counts are: 5000     358
# 6000     290
# 4000     251
# 7200     220
# 4800     119
#         ...
# 19745      1
# 13598      1
# 11549      1
# 26862      1
# 36862      1
# Name: sqft_lot, Length: 9776, dtype: int64
# For column  floors ,the counts are: 1.0    10673
# 2.0     8235
# 1.5     1910
# 3.0      611
# 2.5      161
# 3.5        7
# Name: floors, dtype: int64
# For column  waterfront ,the counts are: 0    21434
# 1      163
# Name: waterfront, dtype: int64
# For column  view ,the counts are: 0    19475
# 2      961
# 3      510
# 1      332
# 4      319
# Name: view, dtype: int64
# For column  condition ,the counts are: 3    14020
# 4     5677
# 5     1701
# 2      170
# 1       29
# Name: condition, dtype: int64
# For column  grade ,the counts are: 7     8974
# 8     6065
# 9     2615
# 6     2038
# 10    1134
# 11     399
# 5      242
# 12      89
# 4       27
# 13      13
# 3        1
# Name: grade, dtype: int64
# For column  sqft_above ,the counts are: 1300    212
# 1010    210
# 1200    206
# 1220    192
# 1140    184
#        ...
# 2198      1
# 6420      1
# 2406      1
# 2502      1
# 2031      1
# Name: sqft_above, Length: 942, dtype: int64
# For column  sqft_basement ,the counts are: 0       13110
# 600       221
# 700       218
# 500       214
# 800       206
#         ...
# 65          1
# 1248        1
# 172         1
# 1920        1
# 1135        1
# Name: sqft_basement, Length: 306, dtype: int64
# For column  yr_built ,the counts are: 2014    559
# 2006    453
# 2005    450
# 2004    433
# 2003    420
#        ...
# 1933     30
# 1901     29
# 1902     27
# 1935     24
# 1934     21
# Name: yr_built, Length: 116, dtype: int64
# For column  yr_renovated ,the counts are: 0       20683
# 2014       91
# 2013       37
# 2003       36
# 2007       35
#         ...
# 1948        1
# 1954        1
# 1951        1
# 1944        1
# 1959        1
# Name: yr_renovated, Length: 70, dtype: int64
# For column  zipcode ,the counts are: 98103    602
# 98038    589
# 98115    583
# 98052    574
# 98117    553
#         ...
# 98102    104
# 98010    100
# 98024     80
# 98148     57
# 98039     50
# Name: zipcode, Length: 70, dtype: int64
# For column  lat ,the counts are: 47.5322    17
# 47.6846    17
# 47.5491    17
# 47.6624    17
# 47.6955    16
#            ..
# 47.3354     1
# 47.3008     1
# 47.3820     1
# 47.4142     1
# 47.2706     1
# Name: lat, Length: 5033, dtype: int64
# For column  long ,the counts are: -122.290    115
# -122.300    111
# -122.362    104
# -122.291    100
# -122.363     99
#            ...
# -121.417      1
# -121.321      1
# -121.737      1
# -122.458      1
# -122.448      1
# Name: long, Length: 751, dtype: int64
# For column  sqft_living15 ,the counts are: 1540    197
# 1440    195
# 1560    192
# 1500    180
# 1460    169
#        ...
# 1399      1
# 1303      1
# 3078      1
# 2822      1
# 2015      1
# Name: sqft_living15, Length: 777, dtype: int64
# For column  sqft_lot15 ,the counts are: 5000     427
# 4000     356
# 6000     288
# 7200     210
# 4800     145
#         ...
# 11816      1
# 1734       1
# 7877       1
# 1718       1
# 2047       1
# Name: sqft_lot15, Length: 8682, dtype: int64
# For column  price ,the counts are: 450000    172
# 350000    172
# 550000    159
# 500000    152
# 425000    150
#          ...
# 554600      1
# 329350      1
# 378510      1
# 212625      1
# 303100      1
# Name: price, Length: 3622, dtype: int64

# %%
target = moddata['price']

# %%
moddata = moddata.drop(['sqft_living','sqft_lot','price'],axis=1)
moddata.shape
# Out:
# (21596, 16)

# %%
moddata.columns
# Out:
# Index(['date', 'bedrooms', 'bathrooms', 'floors', 'waterfront', 'view',
#        'condition', 'grade', 'sqft_above', 'sqft_basement', 'yr_built',
#        'yr_renovated', 'zipcode', 'sqft_living15', 'sqft_lot15', 'day', 'lat',
#        'long'],
#       dtype='object')

# %%
cleandata['grade'].value_counts()
# Out:
# 7     8973
# 8     6065
# 9     2615
# 6     2038
# 10    1134
# 11     399
# 5      242
# 12      89
# 4       27
# 13      13
# 3        1
# Name: grade, dtype: int64

# %%
#idea: make a category for <3 yr reno to replace yr_reno
def newreno(x):
    if ((x == 2014) | (x==2013) | (x==2015)):
        return 'yes'
    else:
        return 'no'

# %%
moddata['new reno']=list(map(newreno,moddata['yr_renovated']))

# %%
pd.reset_option('display.max_rows')
moddata.sort_values(by=['yr_renovated'])
# Out:
#             date  bedrooms  bathrooms  floors  waterfront  view  condition  \
# 0     2014-10-13         3       1.00     1.0           0     0          3
# 14274 2014-10-01         3       2.75     1.5           0     0          5
# 14273 2014-08-14         6       3.00     1.0           0     0          5
# 14272 2014-09-03         3       1.50     1.0           0     0          4
# 14271 2014-12-02         2       1.00     1.0           0     0          5
# ...          ...       ...        ...     ...         ...   ...        ...
# 16669 2015-03-20         4       2.75     1.0           0     0          3
# 7951  2015-03-29         3       1.75     1.0           0     0          3
# 18560 2014-07-01         4       3.00     1.0           0     0          3
# 7410  2015-01-23         4       3.00     2.0           0     0          3
# 2293  2014-07-28         5       2.75     1.5           0     0          3
#
#        grade  sqft_above  sqft_basement  yr_built  yr_renovated  zipcode  \
# 0          7        1180              0      1955             0    98178
# 14274      7        1490            440      1929             0    98105
# 14273      9        2270           1150      1948             0    98006
# 14272      7        1360              0      1955             0    98006
# 14271      7        1400            700      1908             0    98126
# ...      ...         ...            ...       ...           ...      ...
# 16669      8        1170           1230      1961          2015    98058
# 7951       7        1190              0      1952          2015    98178
# 18560      7        1590           1300      1945          2015    98115
# 7410       7        1900              0      1954          2015    98155
# 2293       8        1520            830      1922          2015    98112
#
#        sqft_living15  sqft_lot15  day      lat     long new reno
# 0               1340        5650  164  47.5112 -122.257       no
# 14274           2080        3760  152  47.6659 -122.287       no
# 14273           2430       15560  104  47.5508 -122.189       no
# 14272           1440       11250  124  47.5697 -122.177       no
# 14271           1570        4400  214  47.5740 -122.372       no
# ...              ...         ...  ...      ...      ...      ...
# 16669           1690       20000  322  47.4556 -122.087      yes
# 7951            1200        6000  331  47.5026 -122.236      yes
# 18560           2180        6885   60  47.6763 -122.282      yes
# 7410            1900       12868  266  47.7684 -122.304      yes
# 2293            1920        4178   87  47.6388 -122.300      yes
#
# [21596 rows x 19 columns]

# %%
moddata = moddata.drop(['yr_renovated'],axis=1)

# %%
moddata=moddata.drop(['date'],axis=1)

# %%
for col in moddata.columns:
    print(col, 'has',moddata[col].nunique())
# Out:
# bedrooms has 11
# bathrooms has 29
# floors has 6
# waterfront has 2
# view has 5
# condition has 5
# grade has 11
# sqft_above has 942
# sqft_basement has 306
# yr_built has 116
# zipcode has 70
# sqft_living15 has 777
# sqft_lot15 has 8682
# day has 372
# lat has 5033
# long has 751
# new reno has 2

# %%
def separate(moddata,columns):
    mdata_dis = []
    mdata_cont = []
    for col in columns:
        if len(moddata[col].value_counts())<6:
            print('Col: ',col,' is discrete')
            mdata_dis.append(col)
        else:
            print('Col: ',col,' is continuous')
            mdata_cont.append(col)
    return mdata_dis, mdata_cont

# %%
a,b=separate(moddata,moddata.columns)
# Out:
# Col:  bedrooms  is continuous
# Col:  bathrooms  is continuous
# Col:  floors  is continuous
# Col:  waterfront  is discrete
# Col:  view  is discrete
# Col:  condition  is discrete
# Col:  grade  is continuous
# Col:  sqft_above  is continuous
# Col:  sqft_basement  is continuous
# Col:  yr_built  is continuous
# Col:  zipcode  is continuous
# Col:  sqft_living15  is continuous
# Col:  sqft_lot15  is continuous
# Col:  day  is continuous
# Col:  lat  is continuous
# Col:  long  is continuous
# Col:  new reno  is discrete
# Col:  new bath count  is continuous

# %%
a
# Out:
# ['waterfront', 'view', 'condition', 'new reno']

# %%
moddata.shape
# Out:
# (21596, 18)

# %%
mdis=moddata[a]

# %%
pd.reset_option('display.max_rows')
mcon=moddata[b]
mcon
# Out:
#        bedrooms  bathrooms  floors  grade  sqft_above  sqft_basement  \
# 0             3       1.00     1.0      7        1180              0
# 1             3       2.25     2.0      7        2170            400
# 2             2       1.00     1.0      6         770              0
# 3             4       3.00     1.0      7        1050            910
# 4             3       2.00     1.0      8        1680              0
# ...         ...        ...     ...    ...         ...            ...
# 21592         3       2.50     3.0      8        1530              0
# 21593         4       2.50     2.0      8        2310              0
# 21594         2       0.75     2.0      7        1020              0
# 21595         3       2.50     2.0      8        1600              0
# 21596         2       0.75     2.0      7        1020              0
#
#        yr_built  zipcode  sqft_living15  sqft_lot15  day      lat     long  \
# 0          1955    98178           1340        5650  164  47.5112 -122.257
# 1          1951    98125           1690        7639  221  47.7210 -122.319
# 2          1933    98028           2720        8062  299  47.7379 -122.233
# 3          1965    98136           1360        5000  221  47.5208 -122.393
# 4          1987    98074           1800        7503  292  47.6168 -122.045
# ...         ...      ...            ...         ...  ...      ...      ...
# 21592      2009    98103           1530        1509   19  47.6993 -122.346
# 21593      2014    98146           1830        7200  297  47.5107 -122.362
# 21594      2009    98144           1020        2007   52  47.5944 -122.299
# 21595      2004    98027           1410        1287  259  47.5345 -122.069
# 21596      2008    98144           1020        1357  166  47.5941 -122.299
#
#        new bath count
# 0                 1.0
# 1                 2.5
# 2                 1.0
# 3                 3.0
# 4                 2.0
# ...               ...
# 21592             2.5
# 21593             2.5
# 21594             1.0
# 21595             2.5
# 21596             1.0
#
# [21596 rows x 14 columns]

# %%
cmat = mcon.corr()
sns.heatmap(cmat,annot=True)
plt.show()

# %%
mcon=mcon.drop(['bathrooms'],axis=1)

# %% [markdown]
# # Linear Regression

# %%
from sklearn.preprocessing import Normalizer
transformer = Normalizer().fit(mcon)
x_normalized = transformer.transform(mcon)
print(x_normalized.shape)
# Out:
# (21596, 13)

# %%
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder(handle_unknown='error').fit(mdis)
encoded = encoder.transform(mdis).toarray()

# %%
encodeddf = pd.DataFrame(encoded)

# %%
X = np.concatenate((x_normalized,encodeddf),axis=1)

# %%
x_train,x_test,y_train,y_test = train_test_split(X,target,test_size=0.2,random_state=10000)

# %%
lm = linear_model.LinearRegression()
model = lm.fit(x_train,y_train)
predictions  = lm.predict(x_test)
r2_score(y_test, predictions)
# Out:
# 0.7044717202817021

# %%
plt.scatter(x=y_test,y=predictions)

# %% [markdown]
# # KNeighbors Regressor

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
model = KNeighborsRegressor(n_neighbors=4)
model.fit(x_train,y_train)
predictions  = model.predict(x_test)
score = model.score(x_test,y_test)
lm = linear_model.LinearRegression()
model1 = lm.fit(x_train,y_train)
r2_score(y_test, predictions)
# Out:
# 0.5388044581716877

# %% [markdown]
# # MLP Regressor

# %%
from sklearn.neural_network import MLPRegressor
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
x,y = make_regression(n_samples = 21596,random_state=1)
x_train,x_test,y_train,y_test = train_test_split(x,target,random_state=1)
regr=MLPRegressor(random_state=1,max_iter=1200).fit(x_train,y_train)
regr.predict(x_test[:2])
regr.score(x_test,y_test)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# -0.021012674962856526

# %% [markdown]
# # Logistic Regression
